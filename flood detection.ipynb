# %%
# importing the  nesessary  libraly
import pandas as pd 
import matplotlib.pyplot as plt
from  sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,ConfusionMatrixDisplay

# %%
#how  to read dat from data set
df=pd.read_csv('flood_dataset.csv')
print (df.head(10))
df.columns
# Out:
#    Rainfall   River Level   Soil Moisture   Temp   Humidity   Elevation   \
# 0        320           6.1              65     30         90         155
# 1        290           5.5              60     28         85         150
# 2        310           6.3              68     32         92         160
# 3        300           5.8              63     31         88         158
# 4        280           5.2              60     29         86         152
# 5        330           6.5              70     33         93         157
# 6        295           5.7              64     30         87         154
# 7        305           6.0              66     31         89         159
# 8        285           5.3              61     29         85         153
# 9        315           6.2              67     32         91         156
#
#   Flood Status
# 0        Flood
# 1        Flood
# 2        Flood
# 3        Flood
# 4        Flood
# 5        Flood
# 6        Flood
# 7        Flood
# 8        Flood
# ...

# %%
# sliting  data set  to indipendent  variable  and depentent  variable 
x=df[['Rainfall ', 'River Level ', 'Soil Moisture ', 'Temp ', 'Humidity ', 'Elevation ']]#dependent  variable
y=df['Flood Status']# indipendent  variable

# %%
x
# Out:
#     Rainfall   River Level   Soil Moisture   Temp   Humidity   Elevation
# 0         320           6.1              65     30         90         155
# 1         290           5.5              60     28         85         150
# 2         310           6.3              68     32         92         160
# 3         300           5.8              63     31         88         158
# 4         280           5.2              60     29         86         152
# 5         330           6.5              70     33         93         157
# 6         295           5.7              64     30         87         154
# 7         305           6.0              66     31         89         159
# 8         285           5.3              61     29         85         153
# 9         315           6.2              67     32         91         156
# 10        100           1.8              35     22         70         140
# 11        120           2.0              38     23         72         145
# ...

# %%
print(y)
# Out:
# 0        Flood
# 1        Flood
# 2        Flood
# 3        Flood
# 4        Flood
# 5        Flood
# 6        Flood
# 7        Flood
# 8        Flood
# 9        Flood
# 10    No Flood
# 11    No Flood
# 12    No Flood
# 13    No Flood
# 14    No Flood
# 15    No Flood
# 16    No Flood
# 17    No Flood
# 18    No Flood
# 19    No Flood
# 20       Flood
# 21       Flood
# 22       Flood
# 23       Flood
# 24       Flood
# 25    No Flood
# 26    No Flood
# 27    No Flood
# 28    No Flood
# 29    No Flood
# 30    No Flood
# 31       Flood
# 32       Flood
# 33       Flood
# 34       Flood
# 35       Flood
# 36       Flood
# 37       Flood
# 38    No Flood
# 39    No Flood
# 40    No Flood
# 41    No Flood
# 42    No Flood
# 43    No Flood
# 44    No Flood
# 45    No Flood
# 46       Flood
# 47       Flood
# 48       Flood
# 49       Flood
# 50       Flood
# Name: Flood Status, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# cleat model  and train  and testing  it
model=RandomForestClassifier(n_estimators=100,random_state=0)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_predict=model.predict(x_test)
print (y_predict)
# Out:
# ['No Flood' 'No Flood' 'No Flood' 'Flood' 'Flood' 'No Flood' 'No Flood'
#  'Flood' 'No Flood' 'Flood' 'Flood']

# %%
accuracy= accuracy_score(y_test,y_predict)
print('Model accuracy is :',accuracy) 
print ("Comfusion Morix")
print(confusion_matrix(y_test, y_predict))
# Out:
# Model accuracy is : 1.0
# Comfusion Morix
# [[5 0]
#  [0 6]]

# %%
#  comfusion matrix   for  anlysing the  accuracy  of you model
cm = confusion_matrix(y_test, y_predict, labels=y.unique())
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=y.unique())
disp.plot(cmap=plt.cm.Blues) 
plt.show()

# %%
# ploting  on grath 
plt.figure(figsize=(12,6))
plt.plot(y_test.values[:100], label="Actual", marker='o')
plt.plot(y_predict[:100], label="Predicted", marker='x')
plt.title("Actual vs Predictict flood_Status (first 100 samples)")
plt.xlabel("Sample index")
plt.ylabel("flood_Status")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
feature_importance = pd.Series(model.feature_importances_, index=x.columns)
feature_importance.sort_values().plot(kind='barh', figsize=(8,4), color='skyblue')
plt.title("Past Data")
plt.xlabel("Index")
plt.show()

# %%
import seaborn as sns
sns.pairplot(df, hue="Flood Status")  # remove the extra space
plt.show()

# %%
# saved model  whit  colesponding  name  and extantion 
import pickle
flood_model_prediction= model
with open('flood_model_prediction.pkl','wb') as file:
    pickle.dump(model, file)
